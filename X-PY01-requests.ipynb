# %%
import requests

# %% [markdown]
# #### 网址

# %%
url="http://www.antvv.com"
url="https://www.woyaogexing.com"
r=requests.get(url)
print(r)  #<Response [200]> 返回值对象,返回了一个http状态码
print(type(r))
# Out:
# <Response [200]>
# <class 'requests.models.Response'>

# %% [markdown]
# #### text 获取返回值的源代码,如果误判了编码会乱码

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta property="qc:admins" content="155104645667711775016763757" />
# <meta baidu-gxt-verify-token="779bff2964e2a21475fd6b13985d6864">
# <meta name="shenma-site-verification" content="e46c7d8315678c25acc20c7e067a40c2_1513433091">
# <title>æè¦ä¸ªæ§ç½ - ä¸æ³¨åäº«å¾çãæå­ç­ç´ æï¼å¤´å,å¾ç,ç½å,ä¸ªæ§ç­¾åç­ï¼</title>
# <meta name="Keywords" content="å¾ç,QQå¤´å,ä¸ªæ§ç­¾å,QQç½å,æå­,æè¦ä¸ªæ§ç½">
# <meta name="Description" content="æè¦ä¸ªæ§ç½æ¯ä¸ä¸ªä¸æ³¨åäº«å¾çãæå­ç­ç´ æï¼å¤´å,å¾ç,ç½å,ä¸ªæ§ç­¾åç­ï¼ãæ±éäºæµ·éä¸ªæ§ç±»èµæºï¼å¨è¿éå¯ä»¥å¯»æ¾å°æ¨æ³è¦çãåäº«ä½ åæ¬¢çã">
# <link rel="stylesheet" type="text/css" href="/source/css/common.css?1567576618.css" />
# <script type="text/javascript" src="/source/js/jquery.1.9.js"></script>
# <script type="text/javascript" src="/source/js/common.js"></script>
# </head>
#
# <body>
# <div id="header">
# 	<div class="head wp">
#         <div class="logo z"><h1><a href="https://www.woyaogexing.com">æè¦ä¸ªæ§ç½</a></h1></div>
#         <div class="app_gz z">
#             <a href="/about/about.html" target="_blank">ææº APP</a>
#             <div class="weixin_gz">
#                 <a href="/about/about.html" target="_blank">å®æ¹å¾®ä¿¡</a>
#             </div>
#         </div>
#         <div class="search z">
#             <form action="/e/search/index.php" method="post">
#                 <div class="sele-cur z">
#                 <div class="deft"><span>å¤´å</span><i></i></div>
#                 <ul>
#                     <li data-ns="24">å¤´å</li>
#                     <li data-ns="2">ç½å</li>
#                     <li data-ns="1">ç­¾å</li>
#                     <li data-ns="69">ç®è¤</li>
#                     <li data-ns="63">åç»</li>
#                     <li data-ns="78">æ¥å¿</li>
#                     <li data-ns="75">è¯´è¯´</li>
#                     <li data-ns="85">å¾ç</li>
#                 </ul>
#                 </div>
#                 <input type="text" class="in-key key-focus" name="keyboard" value="è¾å¥å³é®è¯ï¼æ¯å¦ï¼æ¯ä¸ãç±ãEXO">
#                 <input type="hidden" name="classid" class="nsid" value="24" />
#                 <input type="hidden" name="show" value="title" />
#                 <input type="submit" class="srch-btn" value="æç´¢">
#             </form>
#         </div>
#         <div class="login-i y">
#
#         </div>
#     </div>
# </div>
# <!--å¯¼èª-->
# <div id="menu">
#     <ul class="wp">
#         <li class="on"><a href="/">é¦é¡µ</a></li>
#         <li><a href="/gexing/">ä¸ªæ§ç­¾å</a></li>
#         <li><a href="/name/">ç½å</a></li>
#         <li><a href="/touxiang/">å¤´å</a></li>
#         <li><a href="/tupian/">ç¾å¾</a></li>
#         <li><a href="/shouji/">å£çº¸</a></li>
#         <li class="llast"><a href="javascript:;"><span>æ´å¤</span><i></i></a>
#         <div class="sele-gj">
#             <div class="a-ti"><div><em></em></div></div>
#             <div class="a-list">
#             <a href="/gongju/zhuanhuanqi.html" target="_blank">ç¹ä½å­è½¬æ¢å¨</a>
#             <a href="/gongju/fuhaodaquan.html" target="_blank">ç¬¦å·å¤§å¨</a>
#             <a href="/gongju/wangmingsheji.html" target="_blank">ç½åè®¾è®¡</a>
#             <a href="/top/zhtop/">æè¡æ¦</a>
#             </div>
#         </div>
#         </li>
#         <li class="feeback"><a href="/e/tool/feedback/?bid=1" target="_blank">æè§åé¦</a></li>
#     </ul>
# </div>
# <!--ä¸»ä½åå®¹-->
# <div id="indexMain" class="wp mt10 cl">
# 	<div class="indexLeft z">
#     <!--æ ç®åè¡¨-->
#     	<div class="indexLeftA fff border">
#         	<div class="subNav wmILeft">
#             	<h2><a href="/name/">ç½å</a>ï¼</h2><div class="subNavlink">
#                 <a href="/name/ql/" target="_blank">æä¾£ç½å</a><a href="/name/nvsheng/" target="_blank">å¥³çç½å</a><a href="/name/nansheng/" target="_blank">ç·çç½å</a>
#                 <a href="/name/yingwen/" target="_blank">è±æç½å</a>
#                 <a href="/name/zt/" target="_blank">qqç½åç²¾é</a><a href="/name/" class="more" target="_blank">æ´å¤...</a></div>
#             </div>
#             <div class="subNav qmILeft">
#             	<h2><a href="/gexing/">ç­¾å</a>ï¼</h2><div class="subNavlink">
#                 <a href="/gexing/shanggan/" target="_blank">ä¼¤æç­¾å</a><a href="/gexing/chaozhuai/" target="_blank">è¶æ½ç­¾å</a><a href="/gexing/feizhuliou/" target="_blank">éä¸»æµç­¾å</a>
#                 <a href="/gexing/qm/" target="_blank">ç»å¸ç­¾å</a><a href="/gexing/xingfu/" target="_blank">å¹¸ç¦ç­¾å</a><a href="/gexing/aiqing/" target="_blank">ç±æç­¾å</a>
#                 <a href="/gexing/lizhi/" target="_blank">å±å¿ç­¾å</a><a href="/gexing/" class="more" target="_blank">æ´å¤...</a></div>
#             </div>
#             <div class="subNav txILeft">
#             	<h2><a href="/touxiang/">å¤´å</a>ï¼</h2><div class="subNavlink">
#                 <a href="/touxiang/qinglv/" target="_blank">æä¾£å¤´å</a><a href="/touxiang/nv/" target="_blank">å¥³çå¤´å</a><a href="/touxiang/nan/" target="_blank">ç·çå¤´å</a>
#                 <a href="/touxiang/katong/" target="_blank">å¡éå¤´å</a><a href="/touxiang/fengjing/" target="_blank">éç©å¤´å</a><a href="/touxiang/weixin/" target="_blank">å¾®ä¿¡å¤´å</a><a href="/touxiang/" class="more" target="_blank">æ´å¤...</a></div>
#             </div>
#             <div class="subNav pfILeft">
#             	<h2><a href="/shouji/">å£çº¸</a>ï¼</h2><div class="subNavlink">
#                 <a href="/shouji/dongman/" target="_blank">å¨æ¼«å¡é</a><a href="/shouji/mingxing/" target="_blank">ææè½¦æ¨¡</a><a href="/shouji/fengjing/" target="_blank">é£æ¯éç©</a>
#        </div>
# </div>
# <div class="foot wp">
# 	<p>
# 		<a href="/about/about.html" target="_blank">å³äºæè¦ä¸ªæ§</a><span class="dot">|</span>
# 		<a href="/about/copyright.html" target="_blank">çæå£°æ</a><span class="dot">|</span>
# 		<a href="/about/memberAgreement.html" target="_blank">ç¨æ·æå¡åè®®</a><span class="dot">|</span>
# 		<a href="/about/platformGuide.html" target="_blank">ä½¿ç¨æå</a><span class="dot">|</span>
# 		<a href="/about/contact.html" target="_blank">èç³»æä»¬</a><span class="dot">|</span>
# 		<a href="/e/tool/feedback/?bid=1" target="_blank">æè§åé¦</a>
# 	</p>
# 	<p>
# 		Copyright &copy; 2007-2020 <a href="https://www.woyaogexing.com">æè¦ä¸ªæ§ç½ </a> woyaogexing.com
# 	</p>
# 	<p>
# 		åäº¬è´æ¦è¾¾ä¿¡æ¯ææ¯æéå¬å¸  <span class="dot">|</span><a href="http://www.miitbeian.gov.cn/" target="_blank">èICPå¤14032119å·-1</a><span class="dot">|</span><a href="https://www.beian.gov.cn/portal/registerSystemInfo?recordcode=32010502010108" target="_blank"><img src="/source/images/gongan.png"/>  èå¬ç½å®å¤ 32010502010108å·</a><span class="dot">|</span>
# 		<script id="jsgovicon" src="http://odr.jsdsgsxt.gov.cn:8081/mbm/app/main/electronic/js/govicon.js?siteId=11cff3b917074358b2f583617f1d6cf0&width=16&height=20&type=1" type="text/javascript" charset="utf-8"></script>å·¥åç½çå¤æ¡
# 	</p>
# </div>
# <script>
# var _hmt = _hmt || [];
# (function() {
#   var hm = document.createElement("script");
#   hm.src = "https://hm.baidu.com/hm.js?a077b6b44aeefe3829d03416d9cb4ec3";
#   var s = document.getElementsByTagName("script")[0];
#   s.parentNode.insertBefore(hm, s);
# })();
# </script>
# </body>
# </html>

# %% [markdown]
# #### status_code 返回状态码

# %%
print(r.status_code)
# Out:
# 200

# %% [markdown]
# #### encoding 网页的编码,可能会误判

# %%
print(r.encoding)
# Out:
# ISO-8859-1

# %% [markdown]
# #### r.content  返回源代码的字节码,不做解析 ,
# decode(编码类型) 把字节码转换为指定的编码

# %%
print(r.content.decode("utf-8"))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta property="qc:admins" content="155104645667711775016763757" />
# <meta baidu-gxt-verify-token="779bff2964e2a21475fd6b13985d6864">
# <meta name="shenma-site-verification" content="e46c7d8315678c25acc20c7e067a40c2_1513433091">
# <title>我要个性网 - 专注分享图片、文字等素材（头像,图片,网名,个性签名等）</title>
# <meta name="Keywords" content="图片,QQ头像,个性签名,QQ网名,文字,我要个性网">
# <meta name="Description" content="我要个性网是一个专注分享图片、文字等素材（头像,图片,网名,个性签名等）。汇集了海量个性类资源，在这里可以寻找到您想要的、分享你喜欢的。">
# <link rel="stylesheet" type="text/css" href="/source/css/common.css?1567576618.css" />
# <script type="text/javascript" src="/source/js/jquery.1.9.js"></script>
# <script type="text/javascript" src="/source/js/common.js"></script>
# </head>
#
# <body>
# <div id="header">
# 	<div class="head wp">
#         <div class="logo z"><h1><a href="https://www.woyaogexing.com">我要个性网</a></h1></div>
#         <div class="app_gz z">
#             <a href="/about/about.html" target="_blank">手机 APP</a>
#             <div class="weixin_gz">
#                 <a href="/about/about.html" target="_blank">官方微信</a>
#             </div>
#         </div>
#         <div class="search z">
#             <form action="/e/search/index.php" method="post">
#                 <div class="sele-cur z">
#                 <div class="deft"><span>头像</span><i></i></div>
#                 <ul>
#                     <li data-ns="24">头像</li>
#                     <li data-ns="2">网名</li>
#                     <li data-ns="1">签名</li>
#                     <li data-ns="69">皮肤</li>
#                     <li data-ns="63">分组</li>
#                     <li data-ns="78">日志</li>
#                     <li data-ns="75">说说</li>
#                     <li data-ns="85">图片</li>
#                 </ul>
#                 </div>
#                 <input type="text" class="in-key key-focus" name="keyboard" value="输入关键词，比如：毕业、爱、EXO">
#                 <input type="hidden" name="classid" class="nsid" value="24" />
#                 <input type="hidden" name="show" value="title" />
#                 <input type="submit" class="srch-btn" value="搜索">
#             </form>
#         </div>
#         <div class="login-i y">
#
#         </div>
#     </div>
# </div>
# <!--导航-->
# <div id="menu">
#     <ul class="wp">
#         <li class="on"><a href="/">首页</a></li>
#         <li><a href="/gexing/">个性签名</a></li>
#         <li><a href="/name/">网名</a></li>
#         <li><a href="/touxiang/">头像</a></li>
#         <li><a href="/tupian/">美图</a></li>
#         <li><a href="/shouji/">壁纸</a></li>
#         <li class="llast"><a href="javascript:;"><span>更多</span><i></i></a>
#         <div class="sele-gj">
#             <div class="a-ti"><div><em></em></div></div>
#             <div class="a-list">
#             <a href="/gongju/zhuanhuanqi.html" target="_blank">繁体字转换器</a>
#             <a href="/gongju/fuhaodaquan.html" target="_blank">符号大全</a>
#             <a href="/gongju/wangmingsheji.html" target="_blank">网名设计</a>
#             <a href="/top/zhtop/">排行榜</a>
#             </div>
#         </div>
#         </li>
#         <li class="feeback"><a href="/e/tool/feedback/?bid=1" target="_blank">意见反馈</a></li>
#     </ul>
# </div>
# <!--主体内容-->
# <div id="indexMain" class="wp mt10 cl">
# 	<div class="indexLeft z">
#     <!--栏目列表-->
#     	<div class="indexLeftA fff border">
#         	<div class="subNav wmILeft">
#             	<h2><a href="/name/">网名</a>：</h2><div class="subNavlink">
#                 <a href="/name/ql/" target="_blank">情侣网名</a><a href="/name/nvsheng/" target="_blank">女生网名</a><a href="/name/nansheng/" target="_blank">男生网名</a>
#                 <a href="/name/yingwen/" target="_blank">英文网名</a>
#                 <a href="/name/zt/" target="_blank">qq网名精选</a><a href="/name/" class="more" target="_blank">更多...</a></div>
#             </div>
#             <div class="subNav qmILeft">
#             	<h2><a href="/gexing/">签名</a>：</h2><div class="subNavlink">
#                 <a href="/gexing/shanggan/" target="_blank">伤感签名</a><a href="/gexing/chaozhuai/" target="_blank">超拽签名</a><a href="/gexing/feizhuliou/" target="_blank">非主流签名</a>
#                 <a href="/gexing/qm/" target="_blank">经典签名</a><a href="/gexing/xingfu/" target="_blank">幸福签名</a><a href="/gexing/aiqing/" target="_blank">爱情签名</a>
#                 <a href="/gexing/lizhi/" target="_blank">励志签名</a><a href="/gexing/" class="more" target="_blank">更多...</a></div>
#             </div>
#             <div class="subNav txILeft">
#             	<h2><a href="/touxiang/">头像</a>：</h2><div class="subNavlink">
_hmt = _hmt || [];
# (function() {
#   var hm = document.createElement("script");
#   hm.src = "https://hm.baidu.com/hm.js?a077b6b44aeefe3829d03416d9cb4ec3";
#   var s = document.getElementsByTagName("script")[0];
#   s.parentNode.insertBefore(hm, s);
# })();
# </script>
# </body>
# </html>

# %% [markdown]
# #### 尝试请求知乎

# %%
url="https://www.zhihu.com"
url="http://httpbin.org/get"
r=requests.get(url) # 直接请求知乎失败,得到400 错误,因为知乎做了UA(User-Agent)判断
请求 测试网站,发现 UA 是 python-requests/2.18.4,知乎发现了我们是使用爬虫访问的,所以限制了我们,我们需要自己设定UA访问
headers={
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36"
}
r=requests.get(url,headers=headers) # 加上UA了之后就可以访问了
print(r.text)
# Out:
#   File "<ipython-input-10-a755e9b51d5a>", line 4
#     请求 测试网站,发现 UA 是 python-requests/2.18.4,知乎发现了我们是使用爬虫访问的,所以限制了我们,我们需要自己设定UA访问
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### json 字符串处理

# %%
url="http://httpbin.org/get"
headers={
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36"
} 
r=requests.get(url,headers=headers)
# 加上UA了之后就可以访问了
json_str = r.text 
# 返回的类似 字典或者列表的字符串,但是是 str类型, 
# 我们叫它 json字符串 ,是一种数据交换格式,各个语言都有解析json的方式

print(r.text)
print(type(r.text))

# 怎么索引字典的key值？？？？？
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36",
#     "X-Amzn-Trace-Id": "Root=1-5e43a11a-6a7a258a8e3aefc48473591f"
#   },
#   "origin": "113.133.137.163",
#   "url": "http://httpbin.org/get"
# }
#
# <class 'str'>

# %% [markdown]
# #### 引入python的json模块,可以解析 json字符串

# %%
import json

# json.loads() 是把 json字符串转换成  python对象
json_dict=json.loads(json_str)
json_dict=r.json() # requests模块自带的json解析

print(json_dict)
print(type(json_dict))
print(json_dict['origin'])
# Out:
# {'args': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36', 'X-Amzn-Trace-Id': 'Root=1-5e43a045-65ec098373df839c9cc14ff0'}, 'origin': '113.133.137.163', 'url': 'http://httpbin.org/get'}
# <class 'dict'>
# 113.133.137.163

# %% [markdown]
# #### 获取原始内容 stream=True 流式传输

# %%
url="http://www.xiaohuar.com/d/file/20190822/3549081976df334fdd11b6ee53523e34.jpg"
headers={
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36"
}
# r=requests.get(url,headers=headers)
# print(r.text) # 会解析成乱码,因为是一张图片,没有办法通过文本的方式解析
# print(r.content) # 返回原始内容,但是是一次性把整个文件下载下来,如果遇到了大文件,就不好处理了
# 在请求的时候加上 stream= True

r=requests.get(url,headers=headers,stream=True)
# 读取的时候 使用 r.iter_content(num) 每次读取num字节
with open("xiaohuar1.jpg",'wb') as file:
    for j in r.iter_content(10240): #每次读取10240字节= 10kb 写入到文件中
        file.write(j)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~\Anaconda3\lib\http\client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000001666B650400>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='www.xiaohuar.com', port=80): Max retries exceeded with url: /d/file/20190822/3549081976df334fdd11b6ee53523e34.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001666B650400>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-27-0dd388a48bcf> in <module>
#       9 # 在请求的时候加上 stream= True
#      10
# ---> 11 r=requests.get(url,headers=headers,stream=True)
#      12 # 读取的时候 使用 r.iter_content(num) 每次读取num字节
#      13 with open("xiaohuar1.jpg",'wb') as file:
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='www.xiaohuar.com', port=80): Max retries exceeded with url: /d/file/20190822/3549081976df334fdd11b6ee53523e34.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001666B650400>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %% [markdown]
# #### 下载音频

# %%
url="https://m10.music.126.net/20190824144952/faa8f0ca7ae422e8866afadfa3aa62d5/ymusic/0f53/510b/0709/895a49dd17fa7ae02f850c1b4d4df12e.mp3"
r=requests.get(url,headers=headers,stream=True)
with open("孤身.mp3",'wb') as file:
    for j in r.iter_content(10240):
        file.write(j)

# %% [markdown]
# #### get 方式传递参数

# %%
# 1.直接拼接在url后方
url="http://www.antvv.com/?cate=3"

# 2.使用params 参数
url="http://www.antvv.com"

params={
    "cate":"2"
}
r=requests.get(url,params=params)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="zh-CN" lang="zh-CN">
# <head>
# 	<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# 	<meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1">
# 	<meta name="renderer" content="webkit">
# 	<title>PHP - Rose的小站</title>
# 	<meta name="Keywords" content="PHP,Rose的小站">
# 	<meta name="description" content="PHP,Rose的小站,个人博客，会发表一些好文，技术，一些问题也可以留言，我看到后会回答的">
# 	<meta name="generator" content="Z-BlogPHP 1.5.2 Zero" />
# 	<link rel="stylesheet" rev="stylesheet" href="http://www.antvv.com/zb_users/theme/blacklee/style/bootstrap.css" type="text/css" media='all'>
# 	<link rel="stylesheet" rev="stylesheet" href="http://www.antvv.com/zb_users/theme/blacklee/style/blacklee.css" type="text/css" media="all"/>
# 	<link rel="stylesheet" rev="stylesheet" href="http://www.antvv.com/zb_users/theme/blacklee/style/libs/animate.css" type="text/css" media="all"/>
# 	<link rel="stylesheet" href="http://www.antvv.com/zb_users/theme/blacklee/style/font-awesome-4.3.0/css/font-awesome.min.css" media="screen" type="text/css" />
# 	<script src="http://www.antvv.com/zb_system/script/common.js" type="text/javascript"></script>
# 	<script src="http://www.antvv.com/zb_system/script/c_html_js_add.php" type="text/javascript"></script>
# 	<script type="text/javascript" src="http://www.antvv.com/zb_users/theme/blacklee/script/jquery.lazyload.js"></script>
# 	<!--[if lte IE 7]><link rel="stylesheet" href="http://www.antvv.com/zb_users/theme/blacklee/style/font-awesome-4.3.0/css/font-awesome-ie7.min.css"><![endif]-->
# 	<!--[if lt IE 9]><script src="http://www.antvv.com/zb_users/theme/blacklee/script/html5shiv.min.js"></script><![endif]-->
# </head>
# <!--[if lte IE 7]><div id="browsehappy">您正在使用的浏览器版本过低，请<a rel="nofollow" href="http://browsehappy.com/" target="_blank"><strong>升级您的浏览器</strong></a>，获得最佳的浏览体验！</div><![endif]-->
# <body class="container-lee">
# <div id="header_content">
# <header id="header">
# 	<div class="row top-box">
# 		<div class="col-md-8 logo">
# 			<a href="http://www.antvv.com/"><img src="http://www.antvv.com/zb_users/theme//blacklee/style/images/logo.png" alt="Rose的小站"></a>Good Luck To You!		</div>
# 	<div class="col-md-4">
# 		<form class="navbar-form navbar-right" name="search" method="post" action="http://www.antvv.com/zb_system/cmd.php?act=search">
# 			<div class="input-group">
# 				<input class="form-control" name="q" placeholder="请输入搜索内容..." id="s" type="text">
# 				<span class="input-group-btn"><button  class="btn btn-black search-sub" id="btnPost" type="submit"> 搜索 </button></span>
# 			</div>
# 		</form>
# 	</div>
# 	</div>
# 	<nav id="nav" class="header-nav" data-type="category"  data-infoid="2">
# 	<div class="nav-s"><a href="http://www.antvv.com/"><img src="http://www.antvv.com/zb_users/theme//blacklee/style/images/mlogo.png" alt="Rose的小站"></a><i class="fa fa-navicon fa-3x"></i></div>
# 	<div class="nav-sousuo"><!-- Search begin -->
# 		<div class="mini_search">
# 			<form name="search" class="searchform" method="post" action="http://www.antvv.com/zb_system/cmd.php?act=search">
# 				<input class="searchInput" type="text" name="q" size="11" placeholder="请输入搜索内容..." id="ls"/>
# 				<button type="submit" class="btn-search dtb2" value=""><i class="fa fa-search"></i></button>
# 			</form>
# 		</div>
# 		<a id="mo-so" href="javascript:void(0);"><i class="fa fa-search icon-search"></i></a>
# 	</div>
# 	<div class="nav-m">
# 		<ul class="nav nav-pills">
# 			<li id="nvabar-item-index"><a href="http://www.antvv.com/">首页</a></li><li id="navbar-page-2"><a href="http://www.antvv.com/?id=2">留言本</a></li><li id="navbar-category-2"><a href="http://www.antvv.com/?cate=2">PHP</a></li><li id="navbar-category-3"><a href="http://www.antvv.com/?cate=3">散文随笔</a></li><li id="navbar-category-4"><a href="http://www.antvv.com/?cate=4">Python</a></li><li id="navbar-category-5"><a href="http://www.antvv.com/?cate=5">Linux</a></li>		</ul>
# 	</div>
# 	<!--nav--></nav>
# <div class="gg-box gao-gd" id="callboard">
# 	<div class="gg_ul">
# 		<ul style="margin-top: 0px;">
# 			<li><i class="fa fa-bullhorn"></i>欢迎来到Rose的小站！</li><li><i class="fa fa-bullhorn"></i>有问题的话可以联系我.</li>		</ul>
# 	</div>
# 	<!--gg-box--></div>
# </header>
# <section class="containers">
# <div class="main">
# 							<div class="in_box">
# 		<div class="post_box_title">
# 			<h3><i class="fa fa-ioxhost"></i>PHP</h3>		</div>
# 											<article class="post_box">
# 	<div class="post-img col-xs-4  col-sm-4 col-md-4">
# 		<a href="http://www.antvv.com/?id=6">
# 			<img class="img-responsive img-rounded imgs lazy" src="http://www.antvv.com/zb_users/upload/2017/12/201712181513582159824790.png" alt="Thinkphp框架rewrite模式无法打开" style="display: block;"><em></em>
# 		</a>
# 	</div>
# 		<div class="post-left col-xs-8 col-sm-8 col-md-8">
# 			<h3>
# 				<a href="http://www.antvv.com/?id=6" title="Thinkphp框架rewrite模式无法打开">Thinkphp框架rewrite模式无法打开</a>
# 			</h3>
# 			<div class="post-con">
# 							Thinkphp框架有4种url模式，分别为&nbsp;&nbsp;&nbsp;&nbsp;普通模式&nbsp;&nbsp;&nbsp;&nbsp;pathinfo模式&nbsp;&nbsp;&nbsp;&nbsp;re...						</div>
# 			<aside>
# 				<span class="mu-ml"><i class="fa fa-bars"></i> <a href="http://www.antvv.com/?cate=2">PHP</a> </span>
# 				<span><i class="fa fa-eye"></i> 416 次浏览</span>
# 				<span><i class="fa fa-comment"></i><a href="http://www.antvv.com/?id=6#comments">0 条评论</a></span>
# 				<span><i class="fa fa-clock-o"></i>2年前 (2017-12-18)</span>
# 			</aside>
# 		</div>
# </article>										<article class="post_box">
# 	<div class="post-img col-xs-4  col-sm-4 col-md-4">
# 		<a href="http://www.antvv.com/?id=5">
# 			<img class="img-responsive img-rounded imgs lazy" src="http://www.antvv.com/zb_users/upload/2017/11/201711211511253827472794.jpg" alt="关于PHP函数substr和strlen对中文字符串截取乱码和中文长度错误问题" style="display: block;"><em></em>
# 		</a>
# 	</div>
# 		<div class="post-left col-xs-8 col-sm-8 col-md-8">
# 			<h3>
# 				<a href="http://www.antvv.com/?id=5" title="关于PHP函数substr和strlen对中文字符串截取乱码和中文长度错误问题">关于PHP函数substr和strlen对中文字符串截取乱码和中文长度错误问题</a>
# 			</h3>
# 			<div class="post-con">
# 							&nbsp;&nbsp;&nbsp;&nbsp;我们都知道，在PHP里对字符串的操作和数组的操作是最多的，生活中最常用到的字符串函数有strlen(),substr(),strpos(),strstr(),str_rep...						</div>
# 			<aside>
# 				<span class="mu-ml"><i class="fa fa-bars"></i> <a href="http://www.antvv.com/?cate=2">PHP</a> </span>
# 				<span><i class="fa fa-eye"></i> 399 次浏览</span>
# 				<span><i class="fa fa-comment"></i><a href="http://www.antvv.com/?id=5#comments">0 条评论</a></span>
# 				<span><i class="fa fa-clock-o"></i>2年前 (2017-11-21)</span>
# 			</aside>
# 		</div>
# </article>						</div>
# 	<div class="page-a">
# 		<ul class="pagination">
# 			<li><a href="http://www.antvv.com/?cate=2">‹‹</a></li>
# <li class="active"><a>1</a><li>
# <li><a href="http://www.antvv.com/?cate=2">››</a></li>
# 		</ul>
# 	</div>
# </div>
# 	<aside class="sidebar">
#
# <div class="widget" id="divCalendar">
# <span class="icon"><i class="fa fa-reorder"></i></span>
# <div class="divCalendar"><table id="tbCalendar">
#     <caption><a href="http://www.antvv.com/?date=2018-11">«</a>&nbsp;&nbsp;&nbsp;<a href="http://www.antvv.com/?date=2018-12">2018年12月</a>&nbsp;&nbsp;&nbsp;<a href="http://www.antvv.com/?date=2019-1">»</a></caption>
#     <thead><tr> <th title="星期一" scope="col"><small>一</small></th> <th title="星期二" scope="col"><small>二</small></th> <th title="星期三" scope="col"><small>三</small></th> <th title="星期四" scope="col"><small>四</small></th> <th title="星期五" scope="col"><small>五</small></th> <th title="星期六" scope="col"><small>六</small></th> <th title="星期日" scope="col"><small>日</small></th></tr></thead>
#     <tbody>
#     <tr>
# <td class="pad" colspan="5"></td><td>1</td><td>2</td></tr><tr><td>3</td><td>4</td><td>5</td><td>6</td><td>7</td><td>8</td><td>9</td></tr><tr><td><a href="http://www.antvv.com/?date=2018-12-10" title="2018-12-10 (2)" target="_blank">10</a></td><td><a href="http://www.antvv.com/?date=2018-12-11" title="2018-12-11 (1)" target="_blank">11</a></td><td><a href="http://www.antvv.com/?date=2018-12-12" title="2018-12-12 (2)" target="_blank">12</a></td><td>13</td><td>14</td><td>15</td><td>16</td></tr><tr><td>17</td><td>18</td><td>19</td><td>20</td><td>21</td><td>22</td><td>23</td></tr><tr><td>24</td><td>25</td><td>26</td><td>27</td><td>28</td><td>29</td><td>30</td></tr><tr><td>31</td><td class="pad" colspan="5"> </td>	</tr></tbody>
# </table></div>
# </div>
# <div class="widget" id="divContorPanel">
# <span class="icon"><i class="fa fa-reorder"></i></span>
#
_hmt = _hmt || [];
# (function() {
#   var hm = document.createElement("script");
#   hm.src = "https://hm.baidu.com/hm.js?b5de84317ec03bbd2eddac7edb8452bc";
#   var s = document.getElementsByTagName("script")[0];
#   s.parentNode.insertBefore(hm, s);
# })();
# </script>
#
#  安全运行<a id="days">0</a>天 <img width="14" height="16" style="margin-left: 4px;padding-bottom: 3px;
# " src="http://www.antvv.com/zb_users/theme/blacklee/style/images/copy_aq.png">	</p>
# 	<div id="kefu" class="kefu">
# 		<div class="qq"><a href="tencent://message/?uin=164006266&Site=&Menu=yes" target="_blank"><i class="fa fa-qq fa-2x"></i></a></div>				<div class="weixin"><i class="fa fa-weixin fa-2x"></i><img class="pic" src="http://www.antvv.com/zb_users/theme//blacklee/style/images/wxlogo.png" alt="微信二维码"></div>		<div class="top"><i class="fa fa-angle-up fa-2x"></i></div>
# 	</div>
# </footer>
# <div class="pjax_loading"></div>
# <div class="none">
# <script>
# 	var s1 = '2015/11/12';
# 	s1 = new Date(s1.replace(/-/g, "/"));
# 	s2 = new Date();
# 	var days = s2.getTime() - s1.getTime();
# 	var number_of_days = parseInt(days / (1000 * 60 * 60 * 24));
# 	document.getElementById('days').innerHTML = number_of_days;
# </script>
# <script type="text/javascript" src="http://www.antvv.com/zb_users/theme/blacklee/script/blacklee.js"></script>
# <script type="text/javascript" src="http://www.antvv.com/zb_users/theme/blacklee/script/pjax.js" ></script></div>
# </body>
# </html><!--25.38 ms , 22 query , 1121kb memory , 0 error-->

# %% [markdown]
# #### timeout=float   设置超时秒数,
# 如果超过了设定时间,服务器没有返回内容,则报错

# %%
url="https://www.zhihu.com"
try:
    r=requests.get(url,timeout=0.1)
except BaseException:
    print("超时了,")
else:
    print(r.text)
# Out:
# 超时了,

# %% [markdown]
# #### proxies={} 设置代理

# %%
url="http://httpbin.org/get"
proxies={
    "http":"183.166.138.176:808"
}
r=requests.get(url,proxies=proxies)
print(r.text)
# 101.80.14.201 成功后,发现服务器检测到的ip是183.166.138.176
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~\Anaconda3\lib\http\client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000001666B65E780>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='183.166.138.176', port=808): Max retries exceeded with url: http://httpbin.org/get (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001666B65E780>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。')))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# <ipython-input-32-cc462f917f27> in <module>
#       4     "http":"183.166.138.176:808"
#       5 }
# ----> 6 r=requests.get(url,proxies=proxies)
#       7 print(r.text)
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     508
#     509             if isinstance(e.reason, _ProxyError):
# --> 510                 raise ProxyError(e, request=request)
#     511
#     512             if isinstance(e.reason, _SSLError):
#
# ProxyError: HTTPConnectionPool(host='183.166.138.176', port=808): Max retries exceeded with url: http://httpbin.org/get (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001666B65E780>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。')))

# %% [markdown]
# #### 网站请求post接口
# # http://httpbin.org/post

# %%
url="http://httpbin.org/post"
# data 向服务器发送表单数据,一般做模拟登录使用
data={
    "username":"admin1234",
    "password":"888888"
}

# %% [markdown]
# #### files 向服务器发送文件

# %%
files={
    "img":open("xiaohuar.jpg",'rb')
    "html":open("index.html",'rb')
}
# Out:
#   File "<ipython-input-36-28e6c0416f04>", line 3
#     "html":open("index.html",'rb')
#          ^
# SyntaxError: invalid syntax

# %%
# data 向服务器发送json字符串,只需要把data使用json.dumps()转换一下即可

# %%
r=requests.post(url,data=data,files=files)
print(r.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-d7c6a5976934> in <module>
# ----> 1 r=requests.post(url,data=data,files=files)
#       2 print(r.text)
#
# NameError: name 'files' is not defined
